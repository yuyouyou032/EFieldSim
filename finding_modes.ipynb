# %%
import tidy3d as td
import numpy as np
import tidy3d.web as web
# import need be changed in some cases

Air = td.Medium(
    name = 'Air', 
    permittivity = 1.0002, 
)

planewave_0 = td.PlaneWave(
    name = 'planewave_0', 
    center = [-101, 0, -1], 
    size = [0, 300, 300], 
    source_time = td.GaussianPulse(freq0 = 5000000000000, fwidth = 500000000000, ), 
    direction = '+', 
    pol_angle = 1.5707963267948966, 
)

fieldmonitor_0 = td.FieldMonitor(
    name = 'fieldmonitor_0', 
    size = [0, 300, 300], 
    freqs = [991666690774.2797], 
    fields = ['Ex', 'Ey', 'Ez']
)

SiO2_Thz_Regime = td.Medium(
    name = 'SiO2 Thz Regime', 
    permittivity = 4, 
)
box_0 = td.Structure(
    geometry = td.Box(size = [200, 200, 200]), 
    name = 'box_0', 
    medium = SiO2_Thz_Regime
)

LiNbO3_Thz_Regime_300K = td.AnisotropicMedium(
    name = 'LiNbO3 Thz Regime 300K', 
    xx = td.PoleResidue(name = 'LiNbO3_Ord_ThzRegime_300K', frequency_range = [2.7124826971520042e+23, 1.2740247959423027e+24], eps_inf = 11.88604181946721, poles = [[(-5014156491214320000-1.9654459853698072e+24j), (-11220167390769312+18159915184384088000j)], [(-7180621148596394000-2.200800564555081e+25j), (181719280914090160000+3.404314137664228e+26j)]], ), 
    yy = td.PoleResidue(name = 'LiNbO3_Ord_ThzRegime_300K', frequency_range = [2.7124826971520042e+23, 1.2740247959423027e+24], eps_inf = 11.88604181946721, poles = [[(-5014156491214320000-1.9654459853698072e+24j), (-11220167390769312+18159915184384088000j)], [(-7180621148596394000-2.200800564555081e+25j), (181719280914090160000+3.404314137664228e+26j)]], ), 
    zz = td.PoleResidue(name = 'LiNbO3_Extra_ThzRegime_300K', frequency_range = [2.2481498459025096e+23, 9.793435159078609e+23], eps_inf = 18.95737075805664, poles = [[(-769497907620575300000-1.4837252025533907e+25j), (7.36541385625081e+21+4.786664062210221e+25j)], [(-3.823169146627597e+24-5.935291626874599e+24j), (-39213718542055080000+357938460848839600000j)], [(-4.3081684538542086e+23-3.4245516042375175e+24j), (-33097002900980310000+9232982164988277000j)], [(-1.8658183067205696e+24-6.573324543442356e+23j), (131134815777870410000+10857841320676831000j)]], )
)
box_1 = td.Structure(
    geometry = td.Box(center = [0, 0, 100.2], size = [200, 200, 0.4]), 
    name = 'box_1', 
    medium = LiNbO3_Thz_Regime_300K
)


sim = td.Simulation(
    size = [700, 700, 700], 
    grid_spec = td.GridSpec(grid_x = td.AutoGrid(min_steps_per_wvl = 60, ), grid_y = td.AutoGrid(min_steps_per_wvl = 60, ), grid_z = td.AutoGrid(min_steps_per_wvl = 60, ), wavelength = 302.31172235294116, ), 
    version = '2.8.2', 
    run_time = 5e-11,
    medium = Air,
    sources = [planewave_0],
    monitors = [fieldmonitor_0],
    structures = [box_0, box_1],
)
# Out:
# 10:33:43 BST WARNING: 'monitors[0]' contains frequencies outside of the
#              simulation frequency range (3.0000e12, 7.0000e12)(Hz) as defined by
#              the sources.
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.7124826971520042e+23,
#              1.2740247959423027e+24)
#              WARNING: Suppressed 2 WARNING messages.
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.7124826971520042e+23,
#              1.2740247959423027e+24)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.7124826971520042e+23,
#              1.2740247959423027e+24)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.2481498459025096e+23,
#              9.793435159078609e+23)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.7124826971520042e+23,
#              1.2740247959423027e+24)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.7124826971520042e+23,
#              1.2740247959423027e+24)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.2481498459025096e+23,
#              9.793435159078609e+23)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.7124826971520042e+23,
#              1.2740247959423027e+24)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.7124826971520042e+23,
#              1.2740247959423027e+24)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.2481498459025096e+23,
#              9.793435159078609e+23)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.7124826971520042e+23,
#              1.2740247959423027e+24)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.7124826971520042e+23,
#              1.2740247959423027e+24)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.2481498459025096e+23,
#              9.793435159078609e+23)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.7124826971520042e+23,
#              1.2740247959423027e+24)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.7124826971520042e+23,
#              1.2740247959423027e+24)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.2481498459025096e+23,
#              9.793435159078609e+23)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.7124826971520042e+23,
#              1.2740247959423027e+24)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.7124826971520042e+23,
#              1.2740247959423027e+24)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.2481498459025096e+23,
#              9.793435159078609e+23)
#              WARNING: A structure has a nonzero dimension along axis z, which is
#              however too small compared to the generated mesh step along that
#              direction. This could produce unpredictable results. We recommend
#              increasing the resolution, or adding a mesh override structure to
#              ensure that all geometries are at least one pixel thick along all
#              dimensions.

# %%
sources = [[1e12, 5e11], [1.5e12, 5e11], [2e12, 5e11], [2.5e12, 5e11], [3e12, 5e11], [3.5e12, 5e11], [4e12, 5e11], [4.5e12, 5e11], [5e12, 5e11]]
sims = []

# %%
for source in sources:
    planewave = td.PlaneWave(
        name = 'planewave_0', 
        center = [-101, 0, -1], 
        size = [0, 300, 300], 
        source_time = td.GaussianPulse(freq0 = source[0], fwidth = source[1]), 
        direction = '+', 
        pol_angle = 1.5707963267948966, 
    )

    sim = td.Simulation(
        size = [700, 700, 700], 
        grid_spec = td.GridSpec(grid_x = td.AutoGrid(min_steps_per_wvl = 60, ), grid_y = td.AutoGrid(min_steps_per_wvl = 60, ), grid_z = td.AutoGrid(min_steps_per_wvl = 60, ), wavelength = 302.31172235294116, ), 
        version = '2.8.2', 
        run_time = 5e-11,
        medium = Air,
        sources = [planewave],
        monitors = [fieldmonitor_0],
        structures = [box_0, box_1],
    )

    sims.append(sim)
# Out:
# 10:43:52 BST WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.7124826971520042e+23,
#              1.2740247959423027e+24)
#              WARNING: Suppressed 2 WARNING messages.
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.7124826971520042e+23,
#              1.2740247959423027e+24)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.7124826971520042e+23,
#              1.2740247959423027e+24)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.2481498459025096e+23,
#              9.793435159078609e+23)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.7124826971520042e+23,
#              1.2740247959423027e+24)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.7124826971520042e+23,
#              1.2740247959423027e+24)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.2481498459025096e+23,
#              9.793435159078609e+23)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.7124826971520042e+23,
#              1.2740247959423027e+24)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.7124826971520042e+23,
#              1.2740247959423027e+24)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.2481498459025096e+23,
#              9.793435159078609e+23)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.7124826971520042e+23,
#              1.2740247959423027e+24)
# 10:43:53 BST WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.7124826971520042e+23,
#              1.2740247959423027e+24)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.2481498459025096e+23,
#              9.793435159078609e+23)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.7124826971520042e+23,
#              1.2740247959423027e+24)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.7124826971520042e+23,
#              1.2740247959423027e+24)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.2481498459025096e+23,
#              9.793435159078609e+23)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.7124826971520042e+23,
#              1.2740247959423027e+24)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.7124826971520042e+23,
#              1.2740247959423027e+24)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.2481498459025096e+23,
#              9.793435159078609e+23)
#              WARNING: A structure has a nonzero dimension along axis z, which is
#              however too small compared to the generated mesh step along that
#              direction. This could produce unpredictable results. We recommend
#              increasing the resolution, or adding a mesh override structure to
#              ensure that all geometries are at least one pixel thick along all
#              dimensions.
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.7124826971520042e+23,
#              1.2740247959423027e+24)
#              WARNING: Suppressed 2 WARNING messages.
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.7124826971520042e+23,
#              1.2740247959423027e+24)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.7124826971520042e+23,
#              1.2740247959423027e+24)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.2481498459025096e+23,
#              9.793435159078609e+23)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.7124826971520042e+23,
#              1.2740247959423027e+24)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.7124826971520042e+23,
#              1.2740247959423027e+24)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.2481498459025096e+23,
#              9.793435159078609e+23)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.7124826971520042e+23,
#              1.2740247959423027e+24)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.7124826971520042e+23,
#              1.2740247959423027e+24)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.2481498459025096e+23,
#              9.793435159078609e+23)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.7124826971520042e+23,
#              1.2740247959423027e+24)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.7124826971520042e+23,
#              1.2740247959423027e+24)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.2481498459025096e+23,
#              9.793435159078609e+23)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.7124826971520042e+23,
#              1.2740247959423027e+24)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.7124826971520042e+23,
#              1.2740247959423027e+24)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.2481498459025096e+23,
#              9.793435159078609e+23)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.7124826971520042e+23,
#              1.2740247959423027e+24)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.7124826971520042e+23,
#              1.2740247959423027e+24)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.2481498459025096e+23,
#              9.793435159078609e+23)
#              WARNING: A structure has a nonzero dimension along axis z, which is
#              however too small compared to the generated mesh step along that
#              direction. This could produce unpredictable results. We recommend
#              increasing the resolution, or adding a mesh override structure to
#              ensure that all geometries are at least one pixel thick along all
#              dimensions.
# 10:43:54 BST WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.7124826971520042e+23,
#              1.2740247959423027e+24)
#              WARNING: Suppressed 2 WARNING messages.
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.7124826971520042e+23,
#              1.2740247959423027e+24)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.7124826971520042e+23,
#              1.2740247959423027e+24)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.2481498459025096e+23,
#              9.793435159078609e+23)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.7124826971520042e+23,
#              1.2740247959423027e+24)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.7124826971520042e+23,
#              1.2740247959423027e+24)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.2481498459025096e+23,
#              9.793435159078609e+23)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.7124826971520042e+23,
#              1.2740247959423027e+24)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.7124826971520042e+23,
#              1.2740247959423027e+24)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.2481498459025096e+23,
#              9.793435159078609e+23)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.7124826971520042e+23,
#              1.2740247959423027e+24)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.7124826971520042e+23,
#              1.2740247959423027e+24)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.2481498459025096e+23,
#              9.793435159078609e+23)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.7124826971520042e+23,
#              1.2740247959423027e+24)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.7124826971520042e+23,
#              1.2740247959423027e+24)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.2481498459025096e+23,
#              9.793435159078609e+23)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.7124826971520042e+23,
#              1.2740247959423027e+24)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.7124826971520042e+23,
#              1.2740247959423027e+24)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.2481498459025096e+23,
#              9.793435159078609e+23)
#              WARNING: A structure has a nonzero dimension along axis z, which is
#              however too small compared to the generated mesh step along that
#              direction. This could produce unpredictable results. We recommend
#              increasing the resolution, or adding a mesh override structure to
#              ensure that all geometries are at least one pixel thick along all
#              dimensions.
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.7124826971520042e+23,
#              1.2740247959423027e+24)
#              WARNING: Suppressed 2 WARNING messages.
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.7124826971520042e+23,
#              1.2740247959423027e+24)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.7124826971520042e+23,
#              1.2740247959423027e+24)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.2481498459025096e+23,
#              9.793435159078609e+23)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.7124826971520042e+23,
#              1.2740247959423027e+24)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.7124826971520042e+23,
#              1.2740247959423027e+24)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.2481498459025096e+23,
#              9.793435159078609e+23)
# 10:43:55 BST WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.7124826971520042e+23,
#              1.2740247959423027e+24)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.7124826971520042e+23,
#              1.2740247959423027e+24)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.2481498459025096e+23,
#              9.793435159078609e+23)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.7124826971520042e+23,
#              1.2740247959423027e+24)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.7124826971520042e+23,
#              1.2740247959423027e+24)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.2481498459025096e+23,
#              9.793435159078609e+23)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.7124826971520042e+23,
#              1.2740247959423027e+24)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.7124826971520042e+23,
#              1.2740247959423027e+24)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.2481498459025096e+23,
#              9.793435159078609e+23)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.7124826971520042e+23,
#              1.2740247959423027e+24)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.7124826971520042e+23,
#              1.2740247959423027e+24)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.2481498459025096e+23,
#              9.793435159078609e+23)
#              WARNING: A structure has a nonzero dimension along axis z, which is
#              however too small compared to the generated mesh step along that
#              direction. This could produce unpredictable results. We recommend
#              increasing the resolution, or adding a mesh override structure to
#              ensure that all geometries are at least one pixel thick along all
#              dimensions.
#              WARNING: 'monitors[0]' contains frequencies outside of the
#              simulation frequency range (1.0000e12, 5.0000e12)(Hz) as defined by
#              the sources.
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.7124826971520042e+23,
#              1.2740247959423027e+24)
#              WARNING: Suppressed 2 WARNING messages.
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.7124826971520042e+23,
#              1.2740247959423027e+24)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.7124826971520042e+23,
#              1.2740247959423027e+24)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.2481498459025096e+23,
#              9.793435159078609e+23)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.7124826971520042e+23,
#              1.2740247959423027e+24)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.7124826971520042e+23,
#              1.2740247959423027e+24)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.2481498459025096e+23,
#              9.793435159078609e+23)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.7124826971520042e+23,
#              1.2740247959423027e+24)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.7124826971520042e+23,
#              1.2740247959423027e+24)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.2481498459025096e+23,
#              9.793435159078609e+23)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.7124826971520042e+23,
#              1.2740247959423027e+24)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.7124826971520042e+23,
#              1.2740247959423027e+24)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.2481498459025096e+23,
#              9.793435159078609e+23)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.7124826971520042e+23,
#              1.2740247959423027e+24)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.7124826971520042e+23,
#              1.2740247959423027e+24)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.2481498459025096e+23,
#              9.793435159078609e+23)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.7124826971520042e+23,
#              1.2740247959423027e+24)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.7124826971520042e+23,
#              1.2740247959423027e+24)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.2481498459025096e+23,
#              9.793435159078609e+23)
# 10:43:56 BST WARNING: A structure has a nonzero dimension along axis z, which is
#              however too small compared to the generated mesh step along that
#              direction. This could produce unpredictable results. We recommend
#              increasing the resolution, or adding a mesh override structure to
#              ensure that all geometries are at least one pixel thick along all
#              dimensions.
#              WARNING: 'monitors[0]' contains frequencies outside of the
#              simulation frequency range (1.5000e12, 5.5000e12)(Hz) as defined by
#              the sources.
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.7124826971520042e+23,
#              1.2740247959423027e+24)
#              WARNING: Suppressed 2 WARNING messages.
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.7124826971520042e+23,
#              1.2740247959423027e+24)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.7124826971520042e+23,
#              1.2740247959423027e+24)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.2481498459025096e+23,
#              9.793435159078609e+23)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.7124826971520042e+23,
#              1.2740247959423027e+24)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.7124826971520042e+23,
#              1.2740247959423027e+24)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.2481498459025096e+23,
#              9.793435159078609e+23)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.7124826971520042e+23,
#              1.2740247959423027e+24)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.7124826971520042e+23,
#              1.2740247959423027e+24)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.2481498459025096e+23,
#              9.793435159078609e+23)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.7124826971520042e+23,
#              1.2740247959423027e+24)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.7124826971520042e+23,
#              1.2740247959423027e+24)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.2481498459025096e+23,
#              9.793435159078609e+23)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.7124826971520042e+23,
#              1.2740247959423027e+24)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.7124826971520042e+23,
#              1.2740247959423027e+24)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.2481498459025096e+23,
#              9.793435159078609e+23)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.7124826971520042e+23,
#              1.2740247959423027e+24)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.7124826971520042e+23,
#              1.2740247959423027e+24)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.2481498459025096e+23,
#              9.793435159078609e+23)
#              WARNING: A structure has a nonzero dimension along axis z, which is
#              however too small compared to the generated mesh step along that
#              direction. This could produce unpredictable results. We recommend
#              increasing the resolution, or adding a mesh override structure to
#              ensure that all geometries are at least one pixel thick along all
#              dimensions.
#              WARNING: 'monitors[0]' contains frequencies outside of the
#              simulation frequency range (2.0000e12, 6.0000e12)(Hz) as defined by
#              the sources.
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.7124826971520042e+23,
#              1.2740247959423027e+24)
#              WARNING: Suppressed 2 WARNING messages.
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.7124826971520042e+23,
#              1.2740247959423027e+24)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.7124826971520042e+23,
#              1.2740247959423027e+24)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.2481498459025096e+23,
#              9.793435159078609e+23)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.7124826971520042e+23,
#              1.2740247959423027e+24)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.7124826971520042e+23,
#              1.2740247959423027e+24)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.2481498459025096e+23,
#              9.793435159078609e+23)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.7124826971520042e+23,
#              1.2740247959423027e+24)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.7124826971520042e+23,
#              1.2740247959423027e+24)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.2481498459025096e+23,
#              9.793435159078609e+23)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.7124826971520042e+23,
#              1.2740247959423027e+24)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.7124826971520042e+23,
#              1.2740247959423027e+24)
# 10:43:57 BST WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.2481498459025096e+23,
#              9.793435159078609e+23)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.7124826971520042e+23,
#              1.2740247959423027e+24)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.7124826971520042e+23,
#              1.2740247959423027e+24)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.2481498459025096e+23,
#              9.793435159078609e+23)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.7124826971520042e+23,
#              1.2740247959423027e+24)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.7124826971520042e+23,
#              1.2740247959423027e+24)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.2481498459025096e+23,
#              9.793435159078609e+23)
#              WARNING: A structure has a nonzero dimension along axis z, which is
#              however too small compared to the generated mesh step along that
#              direction. This could produce unpredictable results. We recommend
#              increasing the resolution, or adding a mesh override structure to
#              ensure that all geometries are at least one pixel thick along all
#              dimensions.
#              WARNING: 'monitors[0]' contains frequencies outside of the
#              simulation frequency range (2.5000e12, 6.5000e12)(Hz) as defined by
#              the sources.
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.7124826971520042e+23,
#              1.2740247959423027e+24)
#              WARNING: Suppressed 2 WARNING messages.
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.7124826971520042e+23,
#              1.2740247959423027e+24)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.7124826971520042e+23,
#              1.2740247959423027e+24)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.2481498459025096e+23,
#              9.793435159078609e+23)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.7124826971520042e+23,
#              1.2740247959423027e+24)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.7124826971520042e+23,
#              1.2740247959423027e+24)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.2481498459025096e+23,
#              9.793435159078609e+23)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.7124826971520042e+23,
#              1.2740247959423027e+24)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.7124826971520042e+23,
#              1.2740247959423027e+24)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.2481498459025096e+23,
#              9.793435159078609e+23)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.7124826971520042e+23,
#              1.2740247959423027e+24)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.7124826971520042e+23,
#              1.2740247959423027e+24)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.2481498459025096e+23,
#              9.793435159078609e+23)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.7124826971520042e+23,
#              1.2740247959423027e+24)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.7124826971520042e+23,
#              1.2740247959423027e+24)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.2481498459025096e+23,
#              9.793435159078609e+23)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.7124826971520042e+23,
#              1.2740247959423027e+24)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.7124826971520042e+23,
#              1.2740247959423027e+24)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.2481498459025096e+23,
#              9.793435159078609e+23)
#              WARNING: A structure has a nonzero dimension along axis z, which is
#              however too small compared to the generated mesh step along that
#              direction. This could produce unpredictable results. We recommend
#              increasing the resolution, or adding a mesh override structure to
#              ensure that all geometries are at least one pixel thick along all
#              dimensions.
#              WARNING: 'monitors[0]' contains frequencies outside of the
#              simulation frequency range (3.0000e12, 7.0000e12)(Hz) as defined by
#              the sources.
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.7124826971520042e+23,
#              1.2740247959423027e+24)
#              WARNING: Suppressed 2 WARNING messages.
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.7124826971520042e+23,
#              1.2740247959423027e+24)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.7124826971520042e+23,
#              1.2740247959423027e+24)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.2481498459025096e+23,
#              9.793435159078609e+23)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.7124826971520042e+23,
#              1.2740247959423027e+24)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.7124826971520042e+23,
#              1.2740247959423027e+24)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.2481498459025096e+23,
#              9.793435159078609e+23)
# 10:43:58 BST WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.7124826971520042e+23,
#              1.2740247959423027e+24)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.7124826971520042e+23,
#              1.2740247959423027e+24)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.2481498459025096e+23,
#              9.793435159078609e+23)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.7124826971520042e+23,
#              1.2740247959423027e+24)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.7124826971520042e+23,
#              1.2740247959423027e+24)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.2481498459025096e+23,
#              9.793435159078609e+23)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.7124826971520042e+23,
#              1.2740247959423027e+24)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.7124826971520042e+23,
#              1.2740247959423027e+24)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.2481498459025096e+23,
#              9.793435159078609e+23)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.7124826971520042e+23,
#              1.2740247959423027e+24)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.7124826971520042e+23,
#              1.2740247959423027e+24)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.2481498459025096e+23,
#              9.793435159078609e+23)
#              WARNING: A structure has a nonzero dimension along axis z, which is
#              however too small compared to the generated mesh step along that
#              direction. This could produce unpredictable results. We recommend
#              increasing the resolution, or adding a mesh override structure to
#              ensure that all geometries are at least one pixel thick along all
#              dimensions.

# %%
f"{sources[sims.index(sim)][0]:.2E}"
# Out:
# '1.00E+12'

# %%
for sim in sims:
    job = web.Job(simulation=sim, task_name=f"job_{sources[sims.index(sim)][0]:.2E}", verbose=False)
    estimated_cost = web.estimate_cost(job.task_id)
    print(estimated_cost)
    sim_data = web.run(sim,
    task_name="scattered waveguide",
    path=f"data/simulation_{sources[sims.index(sim)][0]}.hdf5",
    verbose=True,)
# Out:
# 10:57:12 BST Maximum FlexCredit cost: 0.306. Minimum cost depends on task
#              execution details. Use 'web.real_cost(task_id)' to get the billed
#              FlexCredit cost after a simulation run.
# 0.30561108555772376
#              Created task 'scattered waveguide' with task_id
#              'fdve-3d10814c-9dfd-470b-9615-402e09dabe28' and task_type 'FDTD'.
#              View task using web UI at
#              ]8;id=642661;https://tidy3d.simulation.cloud/workbench?taskId=fdve-3d10814c-9dfd-470b-9615-402e09dabe28\'https://tidy3d.simulation.cloud/workbench?]8;;\]8;id=435068;https://tidy3d.simulation.cloud/workbench?taskId=fdve-3d10814c-9dfd-470b-9615-402e09dabe28\taskId]8;;\]8;id=642661;https://tidy3d.simulation.cloud/workbench?taskId=fdve-3d10814c-9dfd-470b-9615-402e09dabe28\=]8;;\]8;id=510683;https://tidy3d.simulation.cloud/workbench?taskId=fdve-3d10814c-9dfd-470b-9615-402e09dabe28\fdve]8;;\]8;id=642661;https://tidy3d.simulation.cloud/workbench?taskId=fdve-3d10814c-9dfd-470b-9615-402e09dabe28\-3d10814c-9df]8;;\
#              ]8;id=642661;https://tidy3d.simulation.cloud/workbench?taskId=fdve-3d10814c-9dfd-470b-9615-402e09dabe28\d-470b-9615-402e09dabe28']8;;\.
#              Task folder: ]8;id=239295;https://tidy3d.simulation.cloud/folders/folder-75c58f39-0260-4fe6-85f4-e28fbcd0a51c\'default']8;;\.
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 10:57:14 BST Maximum FlexCredit cost: 0.306. Minimum cost depends on task
#              execution details. Use 'web.real_cost(task_id)' to get the billed
#              FlexCredit cost after a simulation run.
# 10:57:15 BST status = queued
#              To cancel the simulation, use 'web.abort(task_id)' or
#              'web.delete(task_id)' or abort/delete the task in the web UI.
#              Terminating the Python script will not stop the job running on the
#              cloud.
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 10:57:37 BST starting up solver
# 10:57:38 BST running solver
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 10:58:03 BST status = postprocess
# Output()
# 10:58:06 BST status = success
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 10:58:08 BST View simulation result at
#              ]8;id=317817;https://tidy3d.simulation.cloud/workbench?taskId=fdve-3d10814c-9dfd-470b-9615-402e09dabe28\'https://tidy3d.simulation.cloud/workbench?]8;;\]8;id=660616;https://tidy3d.simulation.cloud/workbench?taskId=fdve-3d10814c-9dfd-470b-9615-402e09dabe28\taskId]8;;\]8;id=317817;https://tidy3d.simulation.cloud/workbench?taskId=fdve-3d10814c-9dfd-470b-9615-402e09dabe28\=]8;;\]8;id=263935;https://tidy3d.simulation.cloud/workbench?taskId=fdve-3d10814c-9dfd-470b-9615-402e09dabe28\fdve]8;;\]8;id=317817;https://tidy3d.simulation.cloud/workbench?taskId=fdve-3d10814c-9dfd-470b-9615-402e09dabe28\-3d10814c-9df]8;;\
#              ]8;id=317817;https://tidy3d.simulation.cloud/workbench?taskId=fdve-3d10814c-9dfd-470b-9615-402e09dabe28\d-470b-9615-402e09dabe28']8;;\.
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 10:58:10 BST loading simulation from data/simulation_1000000000000.0.hdf5
# 10:58:11 BST WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.7124826971520042e+23,
#              1.2740247959423027e+24)
#              WARNING: Suppressed 2 WARNING messages.
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.7124826971520042e+23,
#              1.2740247959423027e+24)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.7124826971520042e+23,
#              1.2740247959423027e+24)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.2481498459025096e+23,
#              9.793435159078609e+23)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.7124826971520042e+23,
#              1.2740247959423027e+24)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.7124826971520042e+23,
#              1.2740247959423027e+24)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.2481498459025096e+23,
#              9.793435159078609e+23)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.7124826971520042e+23,
#              1.2740247959423027e+24)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.7124826971520042e+23,
#              1.2740247959423027e+24)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.2481498459025096e+23,
#              9.793435159078609e+23)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.7124826971520042e+23,
#              1.2740247959423027e+24)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.7124826971520042e+23,
#              1.2740247959423027e+24)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.2481498459025096e+23,
#              9.793435159078609e+23)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.7124826971520042e+23,
#              1.2740247959423027e+24)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.7124826971520042e+23,
#              1.2740247959423027e+24)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.2481498459025096e+23,
#              9.793435159078609e+23)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.7124826971520042e+23,
#              1.2740247959423027e+24)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.7124826971520042e+23,
#              1.2740247959423027e+24)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.2481498459025096e+23,
#              9.793435159078609e+23)
#              WARNING: A structure has a nonzero dimension along axis z, which is
#              however too small compared to the generated mesh step along that
#              direction. This could produce unpredictable results. We recommend
#              increasing the resolution, or adding a mesh override structure to
#              ensure that all geometries are at least one pixel thick along all
#              dimensions.
#              WARNING: Simulation final field decay value of 1.15e-05 is greater
#              than the simulation shutoff threshold of 1e-05. Consider running
#              the simulation again with a larger 'run_time' duration for more
#              accurate results.
#              WARNING: Warning messages were found in the solver log. For more
#              information, check 'SimulationData.log' or use
#              'web.download_log(task_id)'.
# 10:58:14 BST Maximum FlexCredit cost: 0.306. Minimum cost depends on task
#              execution details. Use 'web.real_cost(task_id)' to get the billed
#              FlexCredit cost after a simulation run.
# 0.3056122317750379
#              Created task 'scattered waveguide' with task_id
#              'fdve-019c34e4-7fcf-4c78-bfef-904895e337a1' and task_type 'FDTD'.
#              View task using web UI at
#              ]8;id=832697;https://tidy3d.simulation.cloud/workbench?taskId=fdve-019c34e4-7fcf-4c78-bfef-904895e337a1\'https://tidy3d.simulation.cloud/workbench?]8;;\]8;id=777760;https://tidy3d.simulation.cloud/workbench?taskId=fdve-019c34e4-7fcf-4c78-bfef-904895e337a1\taskId]8;;\]8;id=832697;https://tidy3d.simulation.cloud/workbench?taskId=fdve-019c34e4-7fcf-4c78-bfef-904895e337a1\=]8;;\]8;id=873171;https://tidy3d.simulation.cloud/workbench?taskId=fdve-019c34e4-7fcf-4c78-bfef-904895e337a1\fdve]8;;\]8;id=832697;https://tidy3d.simulation.cloud/workbench?taskId=fdve-019c34e4-7fcf-4c78-bfef-904895e337a1\-019c34e4-7fc]8;;\
#              ]8;id=832697;https://tidy3d.simulation.cloud/workbench?taskId=fdve-019c34e4-7fcf-4c78-bfef-904895e337a1\f-4c78-bfef-904895e337a1']8;;\.
#              Task folder: ]8;id=369177;https://tidy3d.simulation.cloud/folders/folder-75c58f39-0260-4fe6-85f4-e28fbcd0a51c\'default']8;;\.
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 10:58:16 BST Maximum FlexCredit cost: 0.306. Minimum cost depends on task
#              execution details. Use 'web.real_cost(task_id)' to get the billed
#              FlexCredit cost after a simulation run.
# 10:58:17 BST status = queued
#              To cancel the simulation, use 'web.abort(task_id)' or
#              'web.delete(task_id)' or abort/delete the task in the web UI.
#              Terminating the Python script will not stop the job running on the
#              cloud.
# Output()
# 11:00:12 BST status = preprocess
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 11:00:16 BST starting up solver
#              running solver
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 11:00:41 BST status = postprocess
# Output()
# 11:00:43 BST status = success
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 11:00:45 BST View simulation result at
#              ]8;id=96185;https://tidy3d.simulation.cloud/workbench?taskId=fdve-019c34e4-7fcf-4c78-bfef-904895e337a1\'https://tidy3d.simulation.cloud/workbench?]8;;\]8;id=559808;https://tidy3d.simulation.cloud/workbench?taskId=fdve-019c34e4-7fcf-4c78-bfef-904895e337a1\taskId]8;;\]8;id=96185;https://tidy3d.simulation.cloud/workbench?taskId=fdve-019c34e4-7fcf-4c78-bfef-904895e337a1\=]8;;\]8;id=630773;https://tidy3d.simulation.cloud/workbench?taskId=fdve-019c34e4-7fcf-4c78-bfef-904895e337a1\fdve]8;;\]8;id=96185;https://tidy3d.simulation.cloud/workbench?taskId=fdve-019c34e4-7fcf-4c78-bfef-904895e337a1\-019c34e4-7fc]8;;\
#              ]8;id=96185;https://tidy3d.simulation.cloud/workbench?taskId=fdve-019c34e4-7fcf-4c78-bfef-904895e337a1\f-4c78-bfef-904895e337a1']8;;\.
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 11:00:49 BST loading simulation from data/simulation_1500000000000.0.hdf5
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.7124826971520042e+23,
#              1.2740247959423027e+24)
#              WARNING: Suppressed 2 WARNING messages.
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.7124826971520042e+23,
#              1.2740247959423027e+24)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.7124826971520042e+23,
#              1.2740247959423027e+24)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.2481498459025096e+23,
#              9.793435159078609e+23)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.7124826971520042e+23,
#              1.2740247959423027e+24)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.7124826971520042e+23,
#              1.2740247959423027e+24)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.2481498459025096e+23,
#              9.793435159078609e+23)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.7124826971520042e+23,
#              1.2740247959423027e+24)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.7124826971520042e+23,
#              1.2740247959423027e+24)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.2481498459025096e+23,
#              9.793435159078609e+23)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.7124826971520042e+23,
#              1.2740247959423027e+24)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.7124826971520042e+23,
#              1.2740247959423027e+24)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.2481498459025096e+23,
#              9.793435159078609e+23)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.7124826971520042e+23,
#              1.2740247959423027e+24)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.7124826971520042e+23,
#              1.2740247959423027e+24)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.2481498459025096e+23,
#              9.793435159078609e+23)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.7124826971520042e+23,
#              1.2740247959423027e+24)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.7124826971520042e+23,
#              1.2740247959423027e+24)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.2481498459025096e+23,
#              9.793435159078609e+23)
#              WARNING: A structure has a nonzero dimension along axis z, which is
#              however too small compared to the generated mesh step along that
#              direction. This could produce unpredictable results. We recommend
#              increasing the resolution, or adding a mesh override structure to
#              ensure that all geometries are at least one pixel thick along all
#              dimensions.
#              WARNING: Simulation final field decay value of 7.39e-05 is greater
#              than the simulation shutoff threshold of 1e-05. Consider running
#              the simulation again with a larger 'run_time' duration for more
#              accurate results.
#              WARNING: Warning messages were found in the solver log. For more
#              information, check 'SimulationData.log' or use
#              'web.download_log(task_id)'.
# 11:00:52 BST Maximum FlexCredit cost: 0.306. Minimum cost depends on task
#              execution details. Use 'web.real_cost(task_id)' to get the billed
#              FlexCredit cost after a simulation run.
# 0.30561340318392055
#              Created task 'scattered waveguide' with task_id
#              'fdve-895153e5-0ec9-4781-816f-77f5a32aad99' and task_type 'FDTD'.
#              View task using web UI at
#              ]8;id=361501;https://tidy3d.simulation.cloud/workbench?taskId=fdve-895153e5-0ec9-4781-816f-77f5a32aad99\'https://tidy3d.simulation.cloud/workbench?]8;;\]8;id=213422;https://tidy3d.simulation.cloud/workbench?taskId=fdve-895153e5-0ec9-4781-816f-77f5a32aad99\taskId]8;;\]8;id=361501;https://tidy3d.simulation.cloud/workbench?taskId=fdve-895153e5-0ec9-4781-816f-77f5a32aad99\=]8;;\]8;id=523823;https://tidy3d.simulation.cloud/workbench?taskId=fdve-895153e5-0ec9-4781-816f-77f5a32aad99\fdve]8;;\]8;id=361501;https://tidy3d.simulation.cloud/workbench?taskId=fdve-895153e5-0ec9-4781-816f-77f5a32aad99\-895153e5-0ec]8;;\
#              ]8;id=361501;https://tidy3d.simulation.cloud/workbench?taskId=fdve-895153e5-0ec9-4781-816f-77f5a32aad99\9-4781-816f-77f5a32aad99']8;;\.
#              Task folder: ]8;id=245927;https://tidy3d.simulation.cloud/folders/folder-75c58f39-0260-4fe6-85f4-e28fbcd0a51c\'default']8;;\.
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 11:00:54 BST Maximum FlexCredit cost: 0.306. Minimum cost depends on task
#              execution details. Use 'web.real_cost(task_id)' to get the billed
#              FlexCredit cost after a simulation run.
# 11:00:55 BST status = queued
#              To cancel the simulation, use 'web.abort(task_id)' or
#              'web.delete(task_id)' or abort/delete the task in the web UI.
#              Terminating the Python script will not stop the job running on the
#              cloud.
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 11:01:35 BST starting up solver
#              running solver
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 11:02:01 BST status = postprocess
# Output()
#              status = success
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 11:02:03 BST View simulation result at
#              ]8;id=450914;https://tidy3d.simulation.cloud/workbench?taskId=fdve-895153e5-0ec9-4781-816f-77f5a32aad99\'https://tidy3d.simulation.cloud/workbench?]8;;\]8;id=266359;https://tidy3d.simulation.cloud/workbench?taskId=fdve-895153e5-0ec9-4781-816f-77f5a32aad99\taskId]8;;\]8;id=450914;https://tidy3d.simulation.cloud/workbench?taskId=fdve-895153e5-0ec9-4781-816f-77f5a32aad99\=]8;;\]8;id=166239;https://tidy3d.simulation.cloud/workbench?taskId=fdve-895153e5-0ec9-4781-816f-77f5a32aad99\fdve]8;;\]8;id=450914;https://tidy3d.simulation.cloud/workbench?taskId=fdve-895153e5-0ec9-4781-816f-77f5a32aad99\-895153e5-0ec]8;;\
#              ]8;id=450914;https://tidy3d.simulation.cloud/workbench?taskId=fdve-895153e5-0ec9-4781-816f-77f5a32aad99\9-4781-816f-77f5a32aad99']8;;\.
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 11:02:05 BST loading simulation from data/simulation_2000000000000.0.hdf5
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.7124826971520042e+23,
#              1.2740247959423027e+24)
#              WARNING: Suppressed 2 WARNING messages.
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.7124826971520042e+23,
#              1.2740247959423027e+24)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.7124826971520042e+23,
#              1.2740247959423027e+24)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.2481498459025096e+23,
#              9.793435159078609e+23)
# 11:02:06 BST WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.7124826971520042e+23,
#              1.2740247959423027e+24)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.7124826971520042e+23,
#              1.2740247959423027e+24)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.2481498459025096e+23,
#              9.793435159078609e+23)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.7124826971520042e+23,
#              1.2740247959423027e+24)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.7124826971520042e+23,
#              1.2740247959423027e+24)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.2481498459025096e+23,
#              9.793435159078609e+23)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.7124826971520042e+23,
#              1.2740247959423027e+24)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.7124826971520042e+23,
#              1.2740247959423027e+24)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.2481498459025096e+23,
#              9.793435159078609e+23)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.7124826971520042e+23,
#              1.2740247959423027e+24)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.7124826971520042e+23,
#              1.2740247959423027e+24)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.2481498459025096e+23,
#              9.793435159078609e+23)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.7124826971520042e+23,
#              1.2740247959423027e+24)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.7124826971520042e+23,
#              1.2740247959423027e+24)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.2481498459025096e+23,
#              9.793435159078609e+23)
#              WARNING: A structure has a nonzero dimension along axis z, which is
#              however too small compared to the generated mesh step along that
#              direction. This could produce unpredictable results. We recommend
#              increasing the resolution, or adding a mesh override structure to
#              ensure that all geometries are at least one pixel thick along all
#              dimensions.
#              WARNING: Simulation final field decay value of 0.000267 is greater
#              than the simulation shutoff threshold of 1e-05. Consider running
#              the simulation again with a larger 'run_time' duration for more
#              accurate results.
#              WARNING: Warning messages were found in the solver log. For more
#              information, check 'SimulationData.log' or use
#              'web.download_log(task_id)'.
# 11:02:09 BST Maximum FlexCredit cost: 0.306. Minimum cost depends on task
#              execution details. Use 'web.real_cost(task_id)' to get the billed
#              FlexCredit cost after a simulation run.
# 0.305614612380164
#              Created task 'scattered waveguide' with task_id
#              'fdve-38abb6f5-2e81-432c-88c6-4e0d6293ba60' and task_type 'FDTD'.
#              View task using web UI at
#              ]8;id=249979;https://tidy3d.simulation.cloud/workbench?taskId=fdve-38abb6f5-2e81-432c-88c6-4e0d6293ba60\'https://tidy3d.simulation.cloud/workbench?]8;;\]8;id=703600;https://tidy3d.simulation.cloud/workbench?taskId=fdve-38abb6f5-2e81-432c-88c6-4e0d6293ba60\taskId]8;;\]8;id=249979;https://tidy3d.simulation.cloud/workbench?taskId=fdve-38abb6f5-2e81-432c-88c6-4e0d6293ba60\=]8;;\]8;id=761266;https://tidy3d.simulation.cloud/workbench?taskId=fdve-38abb6f5-2e81-432c-88c6-4e0d6293ba60\fdve]8;;\]8;id=249979;https://tidy3d.simulation.cloud/workbench?taskId=fdve-38abb6f5-2e81-432c-88c6-4e0d6293ba60\-38abb6f5-2e8]8;;\
#              ]8;id=249979;https://tidy3d.simulation.cloud/workbench?taskId=fdve-38abb6f5-2e81-432c-88c6-4e0d6293ba60\1-432c-88c6-4e0d6293ba60']8;;\.
#              Task folder: ]8;id=281017;https://tidy3d.simulation.cloud/folders/folder-75c58f39-0260-4fe6-85f4-e28fbcd0a51c\'default']8;;\.
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 11:02:11 BST Maximum FlexCredit cost: 0.306. Minimum cost depends on task
#              execution details. Use 'web.real_cost(task_id)' to get the billed
#              FlexCredit cost after a simulation run.
# 11:02:12 BST status = queued
#              To cancel the simulation, use 'web.abort(task_id)' or
#              'web.delete(task_id)' or abort/delete the task in the web UI.
#              Terminating the Python script will not stop the job running on the
#              cloud.
# Output()
# 11:02:28 BST status = preprocess
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 11:02:32 BST starting up solver
#              running solver
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 11:03:11 BST status = success
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#              View simulation result at
#              ]8;id=73449;https://tidy3d.simulation.cloud/workbench?taskId=fdve-38abb6f5-2e81-432c-88c6-4e0d6293ba60\'https://tidy3d.simulation.cloud/workbench?]8;;\]8;id=27768;https://tidy3d.simulation.cloud/workbench?taskId=fdve-38abb6f5-2e81-432c-88c6-4e0d6293ba60\taskId]8;;\]8;id=73449;https://tidy3d.simulation.cloud/workbench?taskId=fdve-38abb6f5-2e81-432c-88c6-4e0d6293ba60\=]8;;\]8;id=420324;https://tidy3d.simulation.cloud/workbench?taskId=fdve-38abb6f5-2e81-432c-88c6-4e0d6293ba60\fdve]8;;\]8;id=73449;https://tidy3d.simulation.cloud/workbench?taskId=fdve-38abb6f5-2e81-432c-88c6-4e0d6293ba60\-38abb6f5-2e8]8;;\
#              ]8;id=73449;https://tidy3d.simulation.cloud/workbench?taskId=fdve-38abb6f5-2e81-432c-88c6-4e0d6293ba60\1-432c-88c6-4e0d6293ba60']8;;\.
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 11:03:13 BST loading simulation from data/simulation_2500000000000.0.hdf5
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.7124826971520042e+23,
#              1.2740247959423027e+24)
#              WARNING: Suppressed 2 WARNING messages.
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.7124826971520042e+23,
#              1.2740247959423027e+24)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.7124826971520042e+23,
#              1.2740247959423027e+24)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.2481498459025096e+23,
#              9.793435159078609e+23)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.7124826971520042e+23,
#              1.2740247959423027e+24)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.7124826971520042e+23,
#              1.2740247959423027e+24)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.2481498459025096e+23,
#              9.793435159078609e+23)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.7124826971520042e+23,
#              1.2740247959423027e+24)
# 11:03:14 BST WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.7124826971520042e+23,
#              1.2740247959423027e+24)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.2481498459025096e+23,
#              9.793435159078609e+23)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.7124826971520042e+23,
#              1.2740247959423027e+24)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.7124826971520042e+23,
#              1.2740247959423027e+24)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.2481498459025096e+23,
#              9.793435159078609e+23)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.7124826971520042e+23,
#              1.2740247959423027e+24)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.7124826971520042e+23,
#              1.2740247959423027e+24)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.2481498459025096e+23,
#              9.793435159078609e+23)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.7124826971520042e+23,
#              1.2740247959423027e+24)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.7124826971520042e+23,
#              1.2740247959423027e+24)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.2481498459025096e+23,
#              9.793435159078609e+23)
#              WARNING: A structure has a nonzero dimension along axis z, which is
#              however too small compared to the generated mesh step along that
#              direction. This could produce unpredictable results. We recommend
#              increasing the resolution, or adding a mesh override structure to
#              ensure that all geometries are at least one pixel thick along all
#              dimensions.
#              WARNING: Simulation final field decay value of 0.000594 is greater
#              than the simulation shutoff threshold of 1e-05. Consider running
#              the simulation again with a larger 'run_time' duration for more
#              accurate results.
#              WARNING: Warning messages were found in the solver log. For more
#              information, check 'SimulationData.log' or use
#              'web.download_log(task_id)'.
# 11:03:17 BST Maximum FlexCredit cost: 0.306. Minimum cost depends on task
#              execution details. Use 'web.real_cost(task_id)' to get the billed
#              FlexCredit cost after a simulation run.
# 0.30561595898503136
#              Created task 'scattered waveguide' with task_id
#              'fdve-ace08452-9935-40a6-84fc-741718f9d88b' and task_type 'FDTD'.
#              View task using web UI at
#              ]8;id=69959;https://tidy3d.simulation.cloud/workbench?taskId=fdve-ace08452-9935-40a6-84fc-741718f9d88b\'https://tidy3d.simulation.cloud/workbench?]8;;\]8;id=502453;https://tidy3d.simulation.cloud/workbench?taskId=fdve-ace08452-9935-40a6-84fc-741718f9d88b\taskId]8;;\]8;id=69959;https://tidy3d.simulation.cloud/workbench?taskId=fdve-ace08452-9935-40a6-84fc-741718f9d88b\=]8;;\]8;id=368155;https://tidy3d.simulation.cloud/workbench?taskId=fdve-ace08452-9935-40a6-84fc-741718f9d88b\fdve]8;;\]8;id=69959;https://tidy3d.simulation.cloud/workbench?taskId=fdve-ace08452-9935-40a6-84fc-741718f9d88b\-ace08452-993]8;;\
#              ]8;id=69959;https://tidy3d.simulation.cloud/workbench?taskId=fdve-ace08452-9935-40a6-84fc-741718f9d88b\5-40a6-84fc-741718f9d88b']8;;\.
#              Task folder: ]8;id=978644;https://tidy3d.simulation.cloud/folders/folder-75c58f39-0260-4fe6-85f4-e28fbcd0a51c\'default']8;;\.
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 11:03:19 BST Maximum FlexCredit cost: 0.306. Minimum cost depends on task
#              execution details. Use 'web.real_cost(task_id)' to get the billed
#              FlexCredit cost after a simulation run.
# 11:03:20 BST status = queued
#              To cancel the simulation, use 'web.abort(task_id)' or
#              'web.delete(task_id)' or abort/delete the task in the web UI.
#              Terminating the Python script will not stop the job running on the
#              cloud.
# Output()
# 11:03:25 BST status = preprocess
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 11:03:29 BST starting up solver
#              running solver
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Output()
# 11:04:09 BST status = postprocess
# 11:04:11 BST status = success
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 11:04:13 BST View simulation result at
#              ]8;id=122038;https://tidy3d.simulation.cloud/workbench?taskId=fdve-ace08452-9935-40a6-84fc-741718f9d88b\'https://tidy3d.simulation.cloud/workbench?]8;;\]8;id=967439;https://tidy3d.simulation.cloud/workbench?taskId=fdve-ace08452-9935-40a6-84fc-741718f9d88b\taskId]8;;\]8;id=122038;https://tidy3d.simulation.cloud/workbench?taskId=fdve-ace08452-9935-40a6-84fc-741718f9d88b\=]8;;\]8;id=975367;https://tidy3d.simulation.cloud/workbench?taskId=fdve-ace08452-9935-40a6-84fc-741718f9d88b\fdve]8;;\]8;id=122038;https://tidy3d.simulation.cloud/workbench?taskId=fdve-ace08452-9935-40a6-84fc-741718f9d88b\-ace08452-993]8;;\
#              ]8;id=122038;https://tidy3d.simulation.cloud/workbench?taskId=fdve-ace08452-9935-40a6-84fc-741718f9d88b\5-40a6-84fc-741718f9d88b']8;;\.
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 11:04:15 BST loading simulation from data/simulation_3000000000000.0.hdf5
# 11:04:16 BST WARNING: 'monitors[0]' contains frequencies outside of the
#              simulation frequency range (1.0000e12, 5.0000e12)(Hz) as defined by
#              the sources.
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.7124826971520042e+23,
#              1.2740247959423027e+24)
#              WARNING: Suppressed 2 WARNING messages.
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.7124826971520042e+23,
#              1.2740247959423027e+24)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.7124826971520042e+23,
#              1.2740247959423027e+24)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.2481498459025096e+23,
#              9.793435159078609e+23)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.7124826971520042e+23,
#              1.2740247959423027e+24)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.7124826971520042e+23,
#              1.2740247959423027e+24)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.2481498459025096e+23,
#              9.793435159078609e+23)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.7124826971520042e+23,
#              1.2740247959423027e+24)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.7124826971520042e+23,
#              1.2740247959423027e+24)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.2481498459025096e+23,
#              9.793435159078609e+23)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.7124826971520042e+23,
#              1.2740247959423027e+24)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.7124826971520042e+23,
#              1.2740247959423027e+24)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.2481498459025096e+23,
#              9.793435159078609e+23)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.7124826971520042e+23,
#              1.2740247959423027e+24)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.7124826971520042e+23,
#              1.2740247959423027e+24)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.2481498459025096e+23,
#              9.793435159078609e+23)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.7124826971520042e+23,
#              1.2740247959423027e+24)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.7124826971520042e+23,
#              1.2740247959423027e+24)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.2481498459025096e+23,
#              9.793435159078609e+23)
#              WARNING: A structure has a nonzero dimension along axis z, which is
#              however too small compared to the generated mesh step along that
#              direction. This could produce unpredictable results. We recommend
#              increasing the resolution, or adding a mesh override structure to
#              ensure that all geometries are at least one pixel thick along all
#              dimensions.
#              WARNING: Simulation final field decay value of 0.000684 is greater
#              than the simulation shutoff threshold of 1e-05. Consider running
#              the simulation again with a larger 'run_time' duration for more
#              accurate results.
#              WARNING: Warning messages were found in the solver log. For more
#              information, check 'SimulationData.log' or use
#              'web.download_log(task_id)'.
# 11:04:19 BST Maximum FlexCredit cost: 0.306. Minimum cost depends on task
#              execution details. Use 'web.real_cost(task_id)' to get the billed
#              FlexCredit cost after a simulation run.
# 0.3056171516921777
#              Created task 'scattered waveguide' with task_id
#              'fdve-54543729-40f4-446e-b712-ac10aa28837c' and task_type 'FDTD'.
#              View task using web UI at
#              ]8;id=915579;https://tidy3d.simulation.cloud/workbench?taskId=fdve-54543729-40f4-446e-b712-ac10aa28837c\'https://tidy3d.simulation.cloud/workbench?]8;;\]8;id=118889;https://tidy3d.simulation.cloud/workbench?taskId=fdve-54543729-40f4-446e-b712-ac10aa28837c\taskId]8;;\]8;id=915579;https://tidy3d.simulation.cloud/workbench?taskId=fdve-54543729-40f4-446e-b712-ac10aa28837c\=]8;;\]8;id=524377;https://tidy3d.simulation.cloud/workbench?taskId=fdve-54543729-40f4-446e-b712-ac10aa28837c\fdve]8;;\]8;id=915579;https://tidy3d.simulation.cloud/workbench?taskId=fdve-54543729-40f4-446e-b712-ac10aa28837c\-54543729-40f]8;;\
#              ]8;id=915579;https://tidy3d.simulation.cloud/workbench?taskId=fdve-54543729-40f4-446e-b712-ac10aa28837c\4-446e-b712-ac10aa28837c']8;;\.
#              Task folder: ]8;id=38687;https://tidy3d.simulation.cloud/folders/folder-75c58f39-0260-4fe6-85f4-e28fbcd0a51c\'default']8;;\.
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 11:04:21 BST Maximum FlexCredit cost: 0.306. Minimum cost depends on task
#              execution details. Use 'web.real_cost(task_id)' to get the billed
#              FlexCredit cost after a simulation run.
# 11:04:22 BST status = queued
#              To cancel the simulation, use 'web.abort(task_id)' or
#              'web.delete(task_id)' or abort/delete the task in the web UI.
#              Terminating the Python script will not stop the job running on the
#              cloud.
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 11:04:31 BST starting up solver
#              running solver
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 11:05:17 BST status = postprocess
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 11:05:21 BST View simulation result at
#              ]8;id=64938;https://tidy3d.simulation.cloud/workbench?taskId=fdve-54543729-40f4-446e-b712-ac10aa28837c\'https://tidy3d.simulation.cloud/workbench?]8;;\]8;id=5250;https://tidy3d.simulation.cloud/workbench?taskId=fdve-54543729-40f4-446e-b712-ac10aa28837c\taskId]8;;\]8;id=64938;https://tidy3d.simulation.cloud/workbench?taskId=fdve-54543729-40f4-446e-b712-ac10aa28837c\=]8;;\]8;id=444465;https://tidy3d.simulation.cloud/workbench?taskId=fdve-54543729-40f4-446e-b712-ac10aa28837c\fdve]8;;\]8;id=64938;https://tidy3d.simulation.cloud/workbench?taskId=fdve-54543729-40f4-446e-b712-ac10aa28837c\-54543729-40f]8;;\
#              ]8;id=64938;https://tidy3d.simulation.cloud/workbench?taskId=fdve-54543729-40f4-446e-b712-ac10aa28837c\4-446e-b712-ac10aa28837c']8;;\.
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 11:05:24 BST loading simulation from data/simulation_3500000000000.0.hdf5
#              WARNING: 'monitors[0]' contains frequencies outside of the
#              simulation frequency range (1.5000e12, 5.5000e12)(Hz) as defined by
#              the sources.
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.7124826971520042e+23,
#              1.2740247959423027e+24)
#              WARNING: Suppressed 2 WARNING messages.
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.7124826971520042e+23,
#              1.2740247959423027e+24)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.7124826971520042e+23,
#              1.2740247959423027e+24)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.2481498459025096e+23,
#              9.793435159078609e+23)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.7124826971520042e+23,
#              1.2740247959423027e+24)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.7124826971520042e+23,
#              1.2740247959423027e+24)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.2481498459025096e+23,
#              9.793435159078609e+23)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.7124826971520042e+23,
#              1.2740247959423027e+24)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
# ...
#              Task folder: ]8;id=280418;https://tidy3d.simulation.cloud/folders/folder-75c58f39-0260-4fe6-85f4-e28fbcd0a51c\'default']8;;\.
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 11:06:42 BST Maximum FlexCredit cost: 0.306. Minimum cost depends on task
#              execution details. Use 'web.real_cost(task_id)' to get the billed
#              FlexCredit cost after a simulation run.
# 11:06:43 BST status = queued
#              To cancel the simulation, use 'web.abort(task_id)' or
#              'web.delete(task_id)' or abort/delete the task in the web UI.
#              Terminating the Python script will not stop the job running on the
#              cloud.
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 11:06:52 BST starting up solver
#              running solver
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 11:07:18 BST status = success
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#              View simulation result at
#              ]8;id=127298;https://tidy3d.simulation.cloud/workbench?taskId=fdve-951559d2-b29b-4341-a106-cce2d40d08f6\'https://tidy3d.simulation.cloud/workbench?]8;;\]8;id=373026;https://tidy3d.simulation.cloud/workbench?taskId=fdve-951559d2-b29b-4341-a106-cce2d40d08f6\taskId]8;;\]8;id=127298;https://tidy3d.simulation.cloud/workbench?taskId=fdve-951559d2-b29b-4341-a106-cce2d40d08f6\=]8;;\]8;id=659641;https://tidy3d.simulation.cloud/workbench?taskId=fdve-951559d2-b29b-4341-a106-cce2d40d08f6\fdve]8;;\]8;id=127298;https://tidy3d.simulation.cloud/workbench?taskId=fdve-951559d2-b29b-4341-a106-cce2d40d08f6\-951559d2-b29]8;;\
#              ]8;id=127298;https://tidy3d.simulation.cloud/workbench?taskId=fdve-951559d2-b29b-4341-a106-cce2d40d08f6\b-4341-a106-cce2d40d08f6']8;;\.
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 11:07:20 BST loading simulation from data/simulation_4500000000000.0.hdf5
#              WARNING: 'monitors[0]' contains frequencies outside of the
#              simulation frequency range (2.5000e12, 6.5000e12)(Hz) as defined by
#              the sources.
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.7124826971520042e+23,
#              1.2740247959423027e+24)
# 11:07:21 BST WARNING: Suppressed 2 WARNING messages.
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.7124826971520042e+23,
#              1.2740247959423027e+24)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.7124826971520042e+23,
#              1.2740247959423027e+24)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.2481498459025096e+23,
#              9.793435159078609e+23)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.7124826971520042e+23,
#              1.2740247959423027e+24)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.7124826971520042e+23,
#              1.2740247959423027e+24)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.2481498459025096e+23,
#              9.793435159078609e+23)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.7124826971520042e+23,
#              1.2740247959423027e+24)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.7124826971520042e+23,
#              1.2740247959423027e+24)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.2481498459025096e+23,
#              9.793435159078609e+23)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.7124826971520042e+23,
#              1.2740247959423027e+24)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.7124826971520042e+23,
#              1.2740247959423027e+24)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.2481498459025096e+23,
#              9.793435159078609e+23)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.7124826971520042e+23,
#              1.2740247959423027e+24)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.7124826971520042e+23,
#              1.2740247959423027e+24)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.2481498459025096e+23,
#              9.793435159078609e+23)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.7124826971520042e+23,
#              1.2740247959423027e+24)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.7124826971520042e+23,
#              1.2740247959423027e+24)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.2481498459025096e+23,
#              9.793435159078609e+23)
#              WARNING: A structure has a nonzero dimension along axis z, which is
#              however too small compared to the generated mesh step along that
#              direction. This could produce unpredictable results. We recommend
#              increasing the resolution, or adding a mesh override structure to
#              ensure that all geometries are at least one pixel thick along all
#              dimensions.
#              WARNING: Simulation final field decay value of 0.00123 is greater
#              than the simulation shutoff threshold of 1e-05. Consider running
#              the simulation again with a larger 'run_time' duration for more
#              accurate results.
#              WARNING: Warning messages were found in the solver log. For more
#              information, check 'SimulationData.log' or use
#              'web.download_log(task_id)'.
# 11:07:24 BST Maximum FlexCredit cost: 0.306. Minimum cost depends on task
#              execution details. Use 'web.real_cost(task_id)' to get the billed
#              FlexCredit cost after a simulation run.
# 0.3056208521423702
#              Created task 'scattered waveguide' with task_id
#              'fdve-f281b2fb-364f-4459-a82a-fd0ce6693713' and task_type 'FDTD'.
#              View task using web UI at
#              ]8;id=783092;https://tidy3d.simulation.cloud/workbench?taskId=fdve-f281b2fb-364f-4459-a82a-fd0ce6693713\'https://tidy3d.simulation.cloud/workbench?]8;;\]8;id=363199;https://tidy3d.simulation.cloud/workbench?taskId=fdve-f281b2fb-364f-4459-a82a-fd0ce6693713\taskId]8;;\]8;id=783092;https://tidy3d.simulation.cloud/workbench?taskId=fdve-f281b2fb-364f-4459-a82a-fd0ce6693713\=]8;;\]8;id=827260;https://tidy3d.simulation.cloud/workbench?taskId=fdve-f281b2fb-364f-4459-a82a-fd0ce6693713\fdve]8;;\]8;id=783092;https://tidy3d.simulation.cloud/workbench?taskId=fdve-f281b2fb-364f-4459-a82a-fd0ce6693713\-f281b2fb-364]8;;\
#              ]8;id=783092;https://tidy3d.simulation.cloud/workbench?taskId=fdve-f281b2fb-364f-4459-a82a-fd0ce6693713\f-4459-a82a-fd0ce6693713']8;;\.
#              Task folder: ]8;id=936505;https://tidy3d.simulation.cloud/folders/folder-75c58f39-0260-4fe6-85f4-e28fbcd0a51c\'default']8;;\.
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 11:07:26 BST Maximum FlexCredit cost: 0.306. Minimum cost depends on task
#              execution details. Use 'web.real_cost(task_id)' to get the billed
#              FlexCredit cost after a simulation run.
# 11:07:27 BST status = queued
#              To cancel the simulation, use 'web.abort(task_id)' or
#              'web.delete(task_id)' or abort/delete the task in the web UI.
#              Terminating the Python script will not stop the job running on the
#              cloud.
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 11:07:34 BST starting up solver
# 11:07:35 BST running solver
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 11:08:00 BST status = postprocess
# Output()
# 11:08:03 BST status = success
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 11:08:05 BST View simulation result at
#              ]8;id=874607;https://tidy3d.simulation.cloud/workbench?taskId=fdve-f281b2fb-364f-4459-a82a-fd0ce6693713\'https://tidy3d.simulation.cloud/workbench?]8;;\]8;id=616029;https://tidy3d.simulation.cloud/workbench?taskId=fdve-f281b2fb-364f-4459-a82a-fd0ce6693713\taskId]8;;\]8;id=874607;https://tidy3d.simulation.cloud/workbench?taskId=fdve-f281b2fb-364f-4459-a82a-fd0ce6693713\=]8;;\]8;id=422805;https://tidy3d.simulation.cloud/workbench?taskId=fdve-f281b2fb-364f-4459-a82a-fd0ce6693713\fdve]8;;\]8;id=874607;https://tidy3d.simulation.cloud/workbench?taskId=fdve-f281b2fb-364f-4459-a82a-fd0ce6693713\-f281b2fb-364]8;;\
#              ]8;id=874607;https://tidy3d.simulation.cloud/workbench?taskId=fdve-f281b2fb-364f-4459-a82a-fd0ce6693713\f-4459-a82a-fd0ce6693713']8;;\.
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 11:08:07 BST loading simulation from data/simulation_5000000000000.0.hdf5
#              WARNING: 'monitors[0]' contains frequencies outside of the
#              simulation frequency range (3.0000e12, 7.0000e12)(Hz) as defined by
#              the sources.
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.7124826971520042e+23,
#              1.2740247959423027e+24)
#              WARNING: Suppressed 2 WARNING messages.
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.7124826971520042e+23,
#              1.2740247959423027e+24)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.7124826971520042e+23,
#              1.2740247959423027e+24)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.2481498459025096e+23,
#              9.793435159078609e+23)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.7124826971520042e+23,
#              1.2740247959423027e+24)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.7124826971520042e+23,
#              1.2740247959423027e+24)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.2481498459025096e+23,
#              9.793435159078609e+23)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.7124826971520042e+23,
#              1.2740247959423027e+24)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.7124826971520042e+23,
#              1.2740247959423027e+24)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.2481498459025096e+23,
#              9.793435159078609e+23)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.7124826971520042e+23,
#              1.2740247959423027e+24)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.7124826971520042e+23,
#              1.2740247959423027e+24)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.2481498459025096e+23,
#              9.793435159078609e+23)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.7124826971520042e+23,
#              1.2740247959423027e+24)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.7124826971520042e+23,
#              1.2740247959423027e+24)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.2481498459025096e+23,
#              9.793435159078609e+23)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.7124826971520042e+23,
#              1.2740247959423027e+24)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.7124826971520042e+23,
#              1.2740247959423027e+24)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (2.2481498459025096e+23,
#              9.793435159078609e+23)
#              WARNING: A structure has a nonzero dimension along axis z, which is
#              however too small compared to the generated mesh step along that
#              direction. This could produce unpredictable results. We recommend
#              increasing the resolution, or adding a mesh override structure to
#              ensure that all geometries are at least one pixel thick along all
#              dimensions.
#              WARNING: Simulation final field decay value of 0.00127 is greater
#              than the simulation shutoff threshold of 1e-05. Consider running
#              the simulation again with a larger 'run_time' duration for more
#              accurate results.
#              WARNING: Warning messages were found in the solver log. For more
#              information, check 'SimulationData.log' or use
#              'web.download_log(task_id)'.
